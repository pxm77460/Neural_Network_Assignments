# %%
# Add more Dense layers to the existing code and check how the accuracy changes
from google.colab import drive


path_to_csv = '/content/breastcancer.csv'

import keras
import pandas as pd
import numpy as np
from keras.models import Sequential
from keras.layers.core import Dense, Activation
from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split

# loading dataset
cancer_data = load_breast_cancer()
X_train, X_test, Y_train, Y_test = train_test_split(cancer_data.data, cancer_data.target,
                                                    test_size=0.25, random_state=87)
np.random.seed(155)
my_nn_model = Sequential() # creating the model
my_nn_model.add(Dense(20, input_dim=30, activation='relu')) # hidden layer 1
my_nn_model.add(Dense(32, activation='relu'))
my_nn_model.add(Dense(1, activation='sigmoid')) # output layer
my_nn_model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['acc'])
my_nn_fitted = my_nn_model.fit(X_train, Y_train, epochs=100,
                         initial_epoch=0)
print(my_nn_model.summary())
print(my_nn_model.evaluate(X_test, Y_test))
# Out:
# Epoch 1/100
# 14/14 [==============================] - 1s 3ms/step - loss: 64.3344 - acc: 0.6197
# Epoch 2/100
# 14/14 [==============================] - 0s 2ms/step - loss: 13.2004 - acc: 0.4531
# Epoch 3/100
# 14/14 [==============================] - 0s 2ms/step - loss: 5.2127 - acc: 0.4131
# Epoch 4/100
# 14/14 [==============================] - 0s 2ms/step - loss: 1.8835 - acc: 0.5329
# Epoch 5/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.9685 - acc: 0.6831
# Epoch 6/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.7304 - acc: 0.7394
# Epoch 7/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.6317 - acc: 0.7653
# Epoch 8/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.5385 - acc: 0.8146
# Epoch 9/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.4529 - acc: 0.8615
# Epoch 10/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.4101 - acc: 0.8474
# Epoch 11/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.4173 - acc: 0.8568
# Epoch 12/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3617 - acc: 0.8709
# Epoch 13/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3361 - acc: 0.8850
# Epoch 14/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3383 - acc: 0.8826
# Epoch 15/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.3212 - acc: 0.8920
# Epoch 16/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3266 - acc: 0.8850
# Epoch 17/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2870 - acc: 0.9108
# Epoch 18/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2791 - acc: 0.8897
# Epoch 19/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2662 - acc: 0.9178
# Epoch 20/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2489 - acc: 0.9131
# Epoch 21/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2512 - acc: 0.9038
# Epoch 22/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2608 - acc: 0.9131
# Epoch 23/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2365 - acc: 0.9108
# Epoch 24/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.2268 - acc: 0.9155
# Epoch 25/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2213 - acc: 0.9178
# Epoch 26/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2319 - acc: 0.9225
# Epoch 27/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2190 - acc: 0.9202
# Epoch 28/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2280 - acc: 0.9131
# Epoch 29/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2167 - acc: 0.9108
# Epoch 30/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.2114 - acc: 0.9249
# Epoch 31/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2148 - acc: 0.9178
# Epoch 32/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2067 - acc: 0.9272
# Epoch 33/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2094 - acc: 0.9249
# Epoch 34/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2073 - acc: 0.9178
# Epoch 35/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2323 - acc: 0.9178
# Epoch 36/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2087 - acc: 0.9108
# Epoch 37/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2253 - acc: 0.9108
# Epoch 38/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2083 - acc: 0.9108
# Epoch 39/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2066 - acc: 0.9155
# Epoch 40/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2017 - acc: 0.9249
# Epoch 41/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2046 - acc: 0.9178
# Epoch 42/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2072 - acc: 0.9272
# Epoch 43/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1949 - acc: 0.9225
# Epoch 44/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2113 - acc: 0.9249
# Epoch 45/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1997 - acc: 0.9296
# Epoch 46/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.2070 - acc: 0.9249
# Epoch 47/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.2009 - acc: 0.9272
# Epoch 48/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2211 - acc: 0.9178
# Epoch 49/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2079 - acc: 0.9225
# Epoch 50/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1911 - acc: 0.9249
# Epoch 51/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2172 - acc: 0.9202
# Epoch 52/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.2012 - acc: 0.9202
# Epoch 53/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1951 - acc: 0.9225
# Epoch 54/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1949 - acc: 0.9249
# Epoch 55/100
# 14/14 [==============================] - 0s 4ms/step - loss: 0.1930 - acc: 0.9155
# Epoch 56/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.1982 - acc: 0.9202
# Epoch 57/100
# 14/14 [==============================] - 0s 4ms/step - loss: 0.1943 - acc: 0.9296
# Epoch 58/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.2124 - acc: 0.9178
# Epoch 59/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.2145 - acc: 0.9249
# Epoch 60/100
# 14/14 [==============================] - 0s 4ms/step - loss: 0.1982 - acc: 0.9178
# Epoch 61/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.2045 - acc: 0.9202
# Epoch 62/100
# 14/14 [==============================] - 0s 5ms/step - loss: 0.2507 - acc: 0.9038
# Epoch 63/100
# 14/14 [==============================] - 0s 4ms/step - loss: 0.1990 - acc: 0.9296
# Epoch 64/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.2036 - acc: 0.9272
# Epoch 65/100
# 14/14 [==============================] - 0s 4ms/step - loss: 0.1955 - acc: 0.9296
# Epoch 66/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.1879 - acc: 0.9249
# Epoch 67/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.1893 - acc: 0.9319
# Epoch 68/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.2250 - acc: 0.9225
# Epoch 69/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.1868 - acc: 0.9343
# Epoch 70/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.2147 - acc: 0.9343
# Epoch 71/100
# 14/14 [==============================] - 0s 4ms/step - loss: 0.1834 - acc: 0.9225
# Epoch 72/100
# 14/14 [==============================] - 0s 4ms/step - loss: 0.1830 - acc: 0.9296
# Epoch 73/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.1942 - acc: 0.9249
# Epoch 74/100
# 14/14 [==============================] - 0s 4ms/step - loss: 0.1948 - acc: 0.9343
# Epoch 75/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.1895 - acc: 0.9343
# Epoch 76/100
# 14/14 [==============================] - 0s 4ms/step - loss: 0.2252 - acc: 0.9178
# Epoch 77/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.2178 - acc: 0.9225
# Epoch 78/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.1830 - acc: 0.9272
# Epoch 79/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.1888 - acc: 0.9249
# Epoch 80/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.2230 - acc: 0.9249
# Epoch 81/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.2004 - acc: 0.9296
# Epoch 82/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.2122 - acc: 0.9272
# Epoch 83/100
# 14/14 [==============================] - 0s 4ms/step - loss: 0.2070 - acc: 0.9202
# Epoch 84/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.1869 - acc: 0.9296
# Epoch 85/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.1734 - acc: 0.9319
# Epoch 86/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.1759 - acc: 0.9296
# Epoch 87/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.2073 - acc: 0.9249
# Epoch 88/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.2480 - acc: 0.9108
# Epoch 89/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.2127 - acc: 0.9225
# Epoch 90/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.1972 - acc: 0.9202
# Epoch 91/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.2362 - acc: 0.9131
# Epoch 92/100
# 14/14 [==============================] - 0s 4ms/step - loss: 0.2301 - acc: 0.9155
# Epoch 93/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.2276 - acc: 0.9085
# Epoch 94/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.2229 - acc: 0.9202
# Epoch 95/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.2008 - acc: 0.9296
# Epoch 96/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.1728 - acc: 0.9319
# Epoch 97/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.1772 - acc: 0.9437
# Epoch 98/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.2356 - acc: 0.9178
# Epoch 99/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.1998 - acc: 0.9202
# Epoch 100/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.1755 - acc: 0.9272
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 20)                620
#
#  dense_1 (Dense)             (None, 32)                672
#
#  dense_2 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 1,325
# Trainable params: 1,325
# Non-trainable params: 0
# _________________________________________________________________
# None
# 5/5 [==============================] - 0s 4ms/step - loss: 0.3191 - acc: 0.8951
# [0.3191284239292145, 0.8951048851013184]

# %%
# Normalize the data before feeding the data to the model and check how the normalization change your accuracy
from google.colab import drive


path_to_csv = '/content/breastcancer.csv'

from sklearn.preprocessing import StandardScaler
sc = StandardScaler()

import keras
import pandas as pd
import numpy as np
from keras.models import Sequential
from keras.layers.core import Dense, Activation
from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split

# loading dataset
cancer_data = load_breast_cancer()
X_train, X_test, Y_train, Y_test = train_test_split(cancer_data.data, cancer_data.target,
                                                    test_size=0.25, random_state=87)
np.random.seed(155)
my_nn_model = Sequential() # creating model
my_nn_model.add(Dense(20, input_dim=30, activation='relu')) # hidden layer 1
my_nn_model.add(Dense(1, activation='sigmoid')) # output layer
my_nn_model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['acc'])
my_nn_fitted = my_nn_model.fit(X_train, Y_train, epochs=100,
                         initial_epoch=0)
print(my_nn_model.summary())
print(my_nn_model.evaluate(X_test, Y_test))
# Out:
# Epoch 1/100
# 14/14 [==============================] - 1s 2ms/step - loss: 4.6067 - acc: 0.4531
# Epoch 2/100
# 14/14 [==============================] - 0s 2ms/step - loss: 1.5741 - acc: 0.7465
# Epoch 3/100
# 14/14 [==============================] - 0s 2ms/step - loss: 1.0837 - acc: 0.8333
# Epoch 4/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.9347 - acc: 0.8474
# Epoch 5/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.7834 - acc: 0.8592
# Epoch 6/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.7646 - acc: 0.8521
# Epoch 7/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.6920 - acc: 0.8662
# Epoch 8/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.7059 - acc: 0.8756
# Epoch 9/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.6648 - acc: 0.8615
# Epoch 10/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.5333 - acc: 0.8897
# Epoch 11/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.6401 - acc: 0.8732
# Epoch 12/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.6051 - acc: 0.8662
# Epoch 13/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.6671 - acc: 0.8779
# Epoch 14/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.5423 - acc: 0.8615
# Epoch 15/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.4222 - acc: 0.9085
# Epoch 16/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.5904 - acc: 0.8662
# Epoch 17/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.4732 - acc: 0.8897
# Epoch 18/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3772 - acc: 0.9014
# Epoch 19/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.4335 - acc: 0.9131
# Epoch 20/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3844 - acc: 0.9014
# Epoch 21/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3195 - acc: 0.9225
# Epoch 22/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3216 - acc: 0.9178
# Epoch 23/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3704 - acc: 0.9038
# Epoch 24/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.3004 - acc: 0.9178
# Epoch 25/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3043 - acc: 0.9178
# Epoch 26/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2730 - acc: 0.9225
# Epoch 27/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2815 - acc: 0.9202
# Epoch 28/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.2739 - acc: 0.9272
# Epoch 29/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.3226 - acc: 0.9038
# Epoch 30/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.3249 - acc: 0.9061
# Epoch 31/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3159 - acc: 0.9272
# Epoch 32/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2747 - acc: 0.9225
# Epoch 33/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.2563 - acc: 0.9272
# Epoch 34/100
# 14/14 [==============================] - 0s 4ms/step - loss: 0.2684 - acc: 0.9249
# Epoch 35/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.3353 - acc: 0.9061
# Epoch 36/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.2692 - acc: 0.9085
# Epoch 37/100
# 14/14 [==============================] - 0s 4ms/step - loss: 0.2433 - acc: 0.9272
# Epoch 38/100
# 14/14 [==============================] - 0s 4ms/step - loss: 0.2939 - acc: 0.9178
# Epoch 39/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.2874 - acc: 0.9085
# Epoch 40/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.2962 - acc: 0.9061
# Epoch 41/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.3429 - acc: 0.9131
# Epoch 42/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.3605 - acc: 0.8850
# Epoch 43/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.2368 - acc: 0.9131
# Epoch 44/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.2749 - acc: 0.9131
# Epoch 45/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.1961 - acc: 0.9413
# Epoch 46/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.2954 - acc: 0.9202
# Epoch 47/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.2335 - acc: 0.9178
# Epoch 48/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.2690 - acc: 0.9202
# Epoch 49/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.3586 - acc: 0.8967
# Epoch 50/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.2453 - acc: 0.9131
# Epoch 51/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.2367 - acc: 0.9272
# Epoch 52/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.2700 - acc: 0.9131
# Epoch 53/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.2398 - acc: 0.9249
# Epoch 54/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.2404 - acc: 0.9249
# Epoch 55/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.1947 - acc: 0.9225
# Epoch 56/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.2366 - acc: 0.9202
# Epoch 57/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.1994 - acc: 0.9319
# Epoch 58/100
# 14/14 [==============================] - 0s 4ms/step - loss: 0.1883 - acc: 0.9366
# Epoch 59/100
# 14/14 [==============================] - 0s 4ms/step - loss: 0.2097 - acc: 0.9296
# Epoch 60/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.2284 - acc: 0.9296
# Epoch 61/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.2404 - acc: 0.9225
# Epoch 62/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.2126 - acc: 0.9272
# Epoch 63/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.2133 - acc: 0.9249
# Epoch 64/100
# 14/14 [==============================] - 0s 4ms/step - loss: 0.2135 - acc: 0.9296
# Epoch 65/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.2730 - acc: 0.9131
# Epoch 66/100
# 14/14 [==============================] - 0s 4ms/step - loss: 0.1749 - acc: 0.9390
# Epoch 67/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.2162 - acc: 0.9225
# Epoch 68/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.3065 - acc: 0.9085
# Epoch 69/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.1730 - acc: 0.9272
# Epoch 70/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.1756 - acc: 0.9272
# Epoch 71/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.2559 - acc: 0.9178
# Epoch 72/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.2053 - acc: 0.9319
# Epoch 73/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.2072 - acc: 0.9413
# Epoch 74/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.2087 - acc: 0.9296
# Epoch 75/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.1944 - acc: 0.9296
# Epoch 76/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.1892 - acc: 0.9366
# Epoch 77/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.2149 - acc: 0.9131
# Epoch 78/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.2492 - acc: 0.9155
# Epoch 79/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.2064 - acc: 0.9343
# Epoch 80/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.1839 - acc: 0.9366
# Epoch 81/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.2513 - acc: 0.9038
# Epoch 82/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.2069 - acc: 0.9225
# Epoch 83/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.1826 - acc: 0.9390
# Epoch 84/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.1855 - acc: 0.9249
# Epoch 85/100
# 14/14 [==============================] - 0s 4ms/step - loss: 0.1625 - acc: 0.9390
# Epoch 86/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.1634 - acc: 0.9319
# Epoch 87/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.1764 - acc: 0.9390
# Epoch 88/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.2697 - acc: 0.9249
# Epoch 89/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.3870 - acc: 0.9038
# Epoch 90/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.3135 - acc: 0.9085
# Epoch 91/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.2055 - acc: 0.9319
# Epoch 92/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.1616 - acc: 0.9413
# Epoch 93/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.1605 - acc: 0.9413
# Epoch 94/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.2549 - acc: 0.9225
# Epoch 95/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.1862 - acc: 0.9413
# Epoch 96/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.2119 - acc: 0.9225
# Epoch 97/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.2042 - acc: 0.9319
# Epoch 98/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.2009 - acc: 0.9366
# Epoch 99/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.1871 - acc: 0.9202
# Epoch 100/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.1877 - acc: 0.9225
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_3 (Dense)             (None, 20)                620
#
#  dense_4 (Dense)             (None, 1)                 21
#
# =================================================================
# Total params: 641
# Trainable params: 641
# Non-trainable params: 0
# _________________________________________________________________
# None
# 5/5 [==============================] - 0s 6ms/step - loss: 0.4087 - acc: 0.8322
# [0.4086824059486389, 0.8321678042411804]

# %%
# Plot the loss and accuracy for both training data and validation data using the history object in the source code
import keras
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Dense, Dropout
import matplotlib.pyplot as plt

# load mnist dataset
(x_train, y_train), (x_test, y_test) = mnist.load_data()

# normalize pixel values to range [0, 1]
x_train = x_train.astype('float32') / 255
x_test = x_test.astype('float32') / 255

# converting class labels to binary class matrices
num_classes = 10
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)

# creating a simple neural network model
model = Sequential()
model.add(Dense(512, activation='relu', input_shape=(784,)))
model.add(Dropout(0.2))
model.add(Dense(512, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(num_classes, activation='softmax'))

model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# training the model and record the training history
history = model.fit(x_train.reshape(-1, 784), y_train, validation_data=(x_test.reshape(-1, 784), y_test),
                    epochs=20, batch_size=128)

# to plot the training and validation accuracy and loss curves
plt.figure(figsize=(10, 5))
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='lower right')

plt.subplot(1, 2, 2)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper right')

plt.show()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 [==============================] - 1s 0us/step
# Epoch 1/20
# 469/469 [==============================] - 12s 24ms/step - loss: 0.2503 - accuracy: 0.9241 - val_loss: 0.1066 - val_accuracy: 0.9682
# Epoch 2/20
# 469/469 [==============================] - 11s 24ms/step - loss: 0.1022 - accuracy: 0.9688 - val_loss: 0.0914 - val_accuracy: 0.9719
# Epoch 3/20
# 469/469 [==============================] - 11s 23ms/step - loss: 0.0728 - accuracy: 0.9769 - val_loss: 0.0661 - val_accuracy: 0.9788
# Epoch 4/20
# 469/469 [==============================] - 11s 24ms/step - loss: 0.0566 - accuracy: 0.9820 - val_loss: 0.0697 - val_accuracy: 0.9778
# Epoch 5/20
# 469/469 [==============================] - 11s 24ms/step - loss: 0.0449 - accuracy: 0.9853 - val_loss: 0.0678 - val_accuracy: 0.9786
# Epoch 6/20
# 469/469 [==============================] - 9s 20ms/step - loss: 0.0385 - accuracy: 0.9875 - val_loss: 0.0683 - val_accuracy: 0.9810
# Epoch 7/20
# 469/469 [==============================] - 12s 27ms/step - loss: 0.0329 - accuracy: 0.9888 - val_loss: 0.0649 - val_accuracy: 0.9793
# Epoch 8/20
# 469/469 [==============================] - 11s 23ms/step - loss: 0.0313 - accuracy: 0.9895 - val_loss: 0.0658 - val_accuracy: 0.9811
# Epoch 9/20
# 469/469 [==============================] - 11s 23ms/step - loss: 0.0284 - accuracy: 0.9905 - val_loss: 0.0696 - val_accuracy: 0.9805
# Epoch 10/20
# 469/469 [==============================] - 11s 23ms/step - loss: 0.0261 - accuracy: 0.9911 - val_loss: 0.0649 - val_accuracy: 0.9828
# Epoch 11/20
# 469/469 [==============================] - 11s 23ms/step - loss: 0.0229 - accuracy: 0.9920 - val_loss: 0.0705 - val_accuracy: 0.9813
# Epoch 12/20
# 469/469 [==============================] - 10s 21ms/step - loss: 0.0211 - accuracy: 0.9928 - val_loss: 0.0675 - val_accuracy: 0.9822
# Epoch 13/20
# 469/469 [==============================] - 11s 23ms/step - loss: 0.0189 - accuracy: 0.9937 - val_loss: 0.0713 - val_accuracy: 0.9828
# Epoch 14/20
# 469/469 [==============================] - 11s 23ms/step - loss: 0.0212 - accuracy: 0.9932 - val_loss: 0.0746 - val_accuracy: 0.9815
# Epoch 15/20
# 469/469 [==============================] - 11s 23ms/step - loss: 0.0199 - accuracy: 0.9934 - val_loss: 0.0712 - val_accuracy: 0.9821
# Epoch 16/20
# 469/469 [==============================] - 11s 23ms/step - loss: 0.0187 - accuracy: 0.9935 - val_loss: 0.0792 - val_accuracy: 0.9811
# Epoch 17/20
# 469/469 [==============================] - 10s 20ms/step - loss: 0.0152 - accuracy: 0.9949 - val_loss: 0.0725 - val_accuracy: 0.9834
# Epoch 18/20
# 469/469 [==============================] - 11s 23ms/step - loss: 0.0159 - accuracy: 0.9945 - val_loss: 0.0812 - val_accuracy: 0.9809
# Epoch 19/20
# 469/469 [==============================] - 11s 23ms/step - loss: 0.0163 - accuracy: 0.9947 - val_loss: 0.0770 - val_accuracy: 0.9838
# Epoch 20/20
# 469/469 [==============================] - 11s 23ms/step - loss: 0.0156 - accuracy: 0.9953 - val_loss: 0.0886 - val_accuracy: 0.9821

# %%
#  Plot one of the images in the test data, and then do inferencing to check what is the prediction of the model on that single image.
import keras
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Dense, Dropout
import matplotlib.pyplot as plt
import numpy as np

# loading mnist dataset
(x_train, y_train), (x_test, y_test) = mnist.load_data()

# normalize pixel values to range [0, 1]
x_train = x_train.astype('float32') / 255
x_test = x_test.astype('float32') / 255

# converting class labels to binary class matrices
num_classes = 10
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)

# to create a simple neural network model
model = Sequential()
model.add(Dense(512, activation='relu', input_shape=(784,)))
model.add(Dropout(0.2))
model.add(Dense(512, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(num_classes, activation='softmax'))

model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# to train the model
model.fit(x_train.reshape(-1, 784), y_train, validation_data=(x_test.reshape(-1, 784), y_test),
          epochs=20, batch_size=128)

# to plot one of the images in the test data
plt.imshow(x_test[0], cmap='gray')
plt.show()

# making a prediction on the image using the trained model
prediction = model.predict(x_test[0].reshape(1, -1))
print('Model prediction:', np.argmax(prediction))
# Out:
# Epoch 1/20
# 469/469 [==============================] - 14s 25ms/step - loss: 0.2450 - accuracy: 0.9266 - val_loss: 0.1162 - val_accuracy: 0.9647
# Epoch 2/20
# 469/469 [==============================] - 11s 23ms/step - loss: 0.1015 - accuracy: 0.9689 - val_loss: 0.0832 - val_accuracy: 0.9748
# Epoch 3/20
# 469/469 [==============================] - 11s 23ms/step - loss: 0.0703 - accuracy: 0.9770 - val_loss: 0.0695 - val_accuracy: 0.9782
# Epoch 4/20
# 469/469 [==============================] - 11s 23ms/step - loss: 0.0573 - accuracy: 0.9811 - val_loss: 0.0702 - val_accuracy: 0.9776
# Epoch 5/20
# 469/469 [==============================] - 11s 23ms/step - loss: 0.0447 - accuracy: 0.9857 - val_loss: 0.0745 - val_accuracy: 0.9773
# Epoch 6/20
# 469/469 [==============================] - 10s 20ms/step - loss: 0.0388 - accuracy: 0.9874 - val_loss: 0.0656 - val_accuracy: 0.9788
# Epoch 7/20
# 469/469 [==============================] - 11s 23ms/step - loss: 0.0338 - accuracy: 0.9881 - val_loss: 0.0653 - val_accuracy: 0.9809
# Epoch 8/20
# 469/469 [==============================] - 11s 24ms/step - loss: 0.0294 - accuracy: 0.9901 - val_loss: 0.0699 - val_accuracy: 0.9810
# Epoch 9/20
# 469/469 [==============================] - 11s 23ms/step - loss: 0.0276 - accuracy: 0.9909 - val_loss: 0.0750 - val_accuracy: 0.9804
# Epoch 10/20
# 469/469 [==============================] - 11s 23ms/step - loss: 0.0237 - accuracy: 0.9924 - val_loss: 0.0754 - val_accuracy: 0.9807
# Epoch 11/20
# 469/469 [==============================] - 10s 21ms/step - loss: 0.0252 - accuracy: 0.9913 - val_loss: 0.0778 - val_accuracy: 0.9815
# Epoch 12/20
# 469/469 [==============================] - 11s 23ms/step - loss: 0.0221 - accuracy: 0.9927 - val_loss: 0.0659 - val_accuracy: 0.9832
# Epoch 13/20
# 469/469 [==============================] - 11s 23ms/step - loss: 0.0170 - accuracy: 0.9941 - val_loss: 0.0720 - val_accuracy: 0.9822
# Epoch 14/20
# 469/469 [==============================] - 11s 23ms/step - loss: 0.0201 - accuracy: 0.9926 - val_loss: 0.0753 - val_accuracy: 0.9837
# Epoch 15/20
# 469/469 [==============================] - 11s 23ms/step - loss: 0.0198 - accuracy: 0.9934 - val_loss: 0.0875 - val_accuracy: 0.9803
# Epoch 16/20
# 469/469 [==============================] - 10s 21ms/step - loss: 0.0160 - accuracy: 0.9945 - val_loss: 0.0828 - val_accuracy: 0.9827
# Epoch 17/20
# 469/469 [==============================] - 11s 23ms/step - loss: 0.0208 - accuracy: 0.9930 - val_loss: 0.0774 - val_accuracy: 0.9815
# Epoch 18/20
# 469/469 [==============================] - 11s 23ms/step - loss: 0.0167 - accuracy: 0.9941 - val_loss: 0.0752 - val_accuracy: 0.9825
# Epoch 19/20
# 469/469 [==============================] - 11s 23ms/step - loss: 0.0143 - accuracy: 0.9950 - val_loss: 0.0842 - val_accuracy: 0.9829
# Epoch 20/20
# 469/469 [==============================] - 11s 23ms/step - loss: 0.0141 - accuracy: 0.9954 - val_loss: 0.0809 - val_accuracy: 0.9832
# 1/1 [==============================] - 0s 90ms/step
# Model prediction: 7

# %%
# We had used 2 hidden layers and Relu activation. Try to change the number of hidden layer and the activation to tanh or sigmoid and see what happens.
import keras
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Dense, Dropout
import matplotlib.pyplot as plt
import numpy as np

# load MNIST dataset
(x_train, y_train), (x_test, y_test) = mnist.load_data()

# normalize pixel values to range [0, 1]
x_train = x_train.astype('float32') / 255
x_test = x_test.astype('float32') / 255

# convert class labels to binary class matrices
num_classes = 10
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)

# create a list of models to train
models = []

# model with 1 hidden layer and tanh activation
model = Sequential()
model.add(Dense(512, activation='tanh', input_shape=(784,)))
model.add(Dropout(0.2))
model.add(Dense(num_classes, activation='softmax'))
models.append(('1 hidden layer with tanh', model))

# model with 1 hidden layer and sigmoid activation
model = Sequential()
model.add(Dense(512, activation='sigmoid', input_shape=(784,)))
model.add(Dropout(0.2))
model.add(Dense(num_classes, activation='softmax'))
models.append(('1 hidden layer with sigmoid', model))

# model with 2 hidden layers and tanh activation
model = Sequential()
model.add(Dense(512, activation='tanh', input_shape=(784,)))
model.add(Dropout(0.2))
model.add(Dense(512, activation='tanh'))
model.add(Dropout(0.2))
model.add(Dense(num_classes, activation='softmax'))
models.append(('2 hidden layers with tanh', model))

# model with 2 hidden layers and sigmoid activation
model = Sequential()
model.add(Dense(512, activation='sigmoid', input_shape=(784,)))
model.add(Dropout(0.2))
model.add(Dense(512, activation='sigmoid'))
model.add(Dropout(0.2))
model.add(Dense(num_classes, activation='softmax'))
models.append(('2 hidden layers with sigmoid', model))

# train each model and plot loss and accuracy curves
for name, model in models:
    model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
    history = model.fit(x_train.reshape(-1, 784), y_train, validation_data=(x_test.reshape(-1, 784), y_test),
                        epochs=20, batch_size=128, verbose=0)
    # plot loss and accuracy curves
    plt.plot(history.history['loss'], label='train_loss')
    plt.plot(history.history['val_loss'], label='val_loss')
    plt.plot(history.history['accuracy'], label='train_accuracy')
    plt.plot(history.history['val_accuracy'], label='val_accuracy')
    plt.title(name)
    plt.xlabel('Epoch')
    plt.legend()
    plt.show()

    # evaluate the model on test data
    loss, accuracy = model.evaluate(x_test.reshape(-1, 784), y_test, verbose=0)
    print('{} - Test loss: {:.4f}, Test accuracy: {:.4f}'.format(name, loss, accuracy))
# Out:
# 1 hidden layer with tanh - Test loss: 0.0637, Test accuracy: 0.9819
# 1 hidden layer with sigmoid - Test loss: 0.0628, Test accuracy: 0.9809
# 2 hidden layers with tanh - Test loss: 0.0782, Test accuracy: 0.9796
# 2 hidden layers with sigmoid - Test loss: 0.0650, Test accuracy: 0.9828

# %%
# Run the same code without scaling the images and check the performance
import keras
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Dense, Dropout
import matplotlib.pyplot as plt
import numpy as np

# load mnist dataset
(x_train, y_train), (x_test, y_test) = mnist.load_data()

# convert class labels to binary class matrices
num_classes = 10
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)

# create a list of models to train
models = []

# model with 1 hidden layer and tanh activation
model = Sequential()
model.add(Dense(512, activation='tanh', input_shape=(784,)))
model.add(Dropout(0.2))
model.add(Dense(num_classes, activation='softmax'))
models.append(('1 hidden layer with tanh', model))

# model with 1 hidden layer and sigmoid activation
model = Sequential()
model.add(Dense(512, activation='sigmoid', input_shape=(784,)))
model.add(Dropout(0.2))
model.add(Dense(num_classes, activation='softmax'))
models.append(('1 hidden layer with sigmoid', model))

# model with 2 hidden layers and tanh activation
model = Sequential()
model.add(Dense(512, activation='tanh', input_shape=(784,)))
model.add(Dropout(0.2))
model.add(Dense(512, activation='tanh'))
model.add(Dropout(0.2))
model.add(Dense(num_classes, activation='softmax'))
models.append(('2 hidden layers with tanh', model))

# model with 2 hidden layers and sigmoid activation
model = Sequential()
model.add(Dense(512, activation='sigmoid', input_shape=(784,)))
model.add(Dropout(0.2))
model.add(Dense(512, activation='sigmoid'))
model.add(Dropout(0.2))
model.add(Dense(num_classes, activation='softmax'))
models.append(('2 hidden layers with sigmoid', model))

# train each model and plot loss and accuracy curves
for name, model in models:
    model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
    history = model.fit(x_train.reshape(-1, 784), y_train, validation_data=(x_test.reshape(-1, 784), y_test),
                        epochs=20, batch_size=128, verbose=0)
    # plot loss and accuracy curves
    plt.plot(history.history['loss'], label='train_loss')
    plt.plot(history.history['val_loss'], label='val_loss')
    plt.plot(history.history['accuracy'], label='train_accuracy')
    plt.plot(history.history['val_accuracy'], label='val_accuracy')
    plt.title(name)
    plt.xlabel('Epoch')
    plt.legend()
    plt.show()

    # evaluate the model on test data
    loss, accuracy = model.evaluate(x_test.reshape(-1, 784), y_test, verbose=0)
    print('{} - Test loss: {:.4f}, Test accuracy: {:.4f}'.format(name, loss, accuracy))
# Out:
# 1 hidden layer with tanh - Test loss: 0.1864, Test accuracy: 0.9438
# 1 hidden layer with sigmoid - Test loss: 0.1417, Test accuracy: 0.9592
# 2 hidden layers with tanh - Test loss: 0.1324, Test accuracy: 0.9603
# 2 hidden layers with sigmoid - Test loss: 0.1059, Test accuracy: 0.9667
